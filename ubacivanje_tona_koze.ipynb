# %%
import pandas as pd

# %%
#Ucitavanje fajlova
results_df = pd.read_csv("result.csv")
cleaned_df = pd.read_csv("ocisceni_podaci.csv")

# %%
# Uklanjamo .jpg iz kolone 'file'
results_df['file_clean'] = results_df['file'].str.replace('.jpg', '', regex=False)

# %%
#provera
results_df.head(1)
# Out:
#                file image type  face id dominant 1  percent 1 dominant 2  \
# 0  ISIC_0015719.jpg      color      NaN    #E2AF8E       0.75    #BF8761
#
#    percent 2 skin tone tone label  accuracy(0-100)    file_clean
# 0       0.25   #D7BD96         CE            88.81  ISIC_0015719

# %%
# Spojamo kolonu skin tone sa odgovarajucom slikom u ocisceni_podaci.csv: image_name == file_clean
merged_df = cleaned_df.merge(results_df[['file_clean', 'skin tone']],
                                      left_on='image_name',
                                      right_on='file_clean',
                                      how='left')

# %%
# Uklonjamo pomoćnu kolonu
merged_df.drop(columns=['file_clean'], inplace=True)

# %%
#provera
merged_df.head(10)
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
# 5  ISIC_0074311  IP_2950485  female        40.0               lower extremity
# 6  ISIC_0074542  IP_4698288    male        25.0               lower extremity
# 7  ISIC_0075663  IP_6017204  female        35.0                         torso
# 8  ISIC_0075914  IP_7622888    male        30.0                         torso
# 9  ISIC_0076262  IP_5075533  female        50.0               lower extremity
#
#   diagnosis benign_malignant  target skin tone
# 0   unknown           benign       0   #F3E7DB
# 1   unknown           benign       0   #D7BD96
# 2     nevus           benign       0   #604134
# 3   unknown           benign       0   #604134
# 4   unknown           benign       0   #D7BD96
# 5   unknown           benign       0   #F3E7DB
# 6   unknown           benign       0   #F3E7DB
# 7   unknown           benign       0   #D7BD96
# 8   unknown           benign       0   #F3E7DB
# 9   unknown           benign       0   #F3E7DB

# %%
merged_df.to_csv("ocisceni_podaci_sa_tonom_koze.csv", index=False)
