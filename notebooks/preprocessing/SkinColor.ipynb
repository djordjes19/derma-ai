# %%
import sys
import os

# Idi dva koraka unazad (iz preprocessing u project), pa uđi u scripts/
sys.path.append(os.path.abspath(os.path.join("..", "..", "scripts")))
from  MonkScale import  analyze_skin_images_in_folder

# Primer korišćenja
folder_path = os.path.abspath(os.path.join("..", "..", "data", "raw", "train"))
num_images = 15

# Analiza slika 
analyze_skin_images_in_folder(folder_path, 1)

# Ili možete koristiti samo funkciju za klasifikaciju pojedinačne slike
