# %% [markdown]
# This script is used for plotting the balanced dataset

# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..', 'exploration'))
if module_path not in sys.path:
    sys.path.append(module_path)

from plot_utils import plot_skin_tone_distribution_v2

# %%
#Load dataset
df = pd.read_csv("../../data/balanced_data.csv")

# %%
#Plot dataset
plot_skin_tone_distribution_v2(df)
