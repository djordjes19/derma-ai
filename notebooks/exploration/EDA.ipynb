# %%
from  plot_utils import plot_attribute, plot_skin_tone_distribution
import pandas as pd

# %%
df = pd.read_csv('../../ocisceni_podaci_sa_tonom_koze.csv')

# %%
df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target skin_tone
# 0   unknown           benign       0   #F3E7DB
# 1   unknown           benign       0   #D7BD96
# 2     nevus           benign       0   #604134
# 3   unknown           benign       0   #604134
# 4   unknown           benign       0   #D7BD96

# %%
plot_attribute(df,"benign_malignant")
print(df[df['benign_malignant'] == 'benign'].count())
df[df['benign_malignant'] == 'malignant'].count()
df.count()
# Out:
# C:\biznis\derma-ai\notebooks\exploration\plot_utils.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(value_counts.index, rotation=45, ha='right')
# image_name                       31956
# patient_id                       31956
# sex                              31956
# age_approx                       31956
# anatom_site_general_challenge    31956
# diagnosis                        31956
# benign_malignant                 31956
# target                           31956
# skin_tone                        31956
# dtype: int64
# image_name                       32531
# patient_id                       32531
# sex                              32531
# age_approx                       32531
# anatom_site_general_challenge    32531
# diagnosis                        32531
# benign_malignant                 32531
# target                           32531
# ...

# %%
plot_skin_tone_distribution(df)

# %%
df1 = pd.read_csv()
